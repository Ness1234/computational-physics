# %%
# Trap.py trapezoid integration of t^2 
# A, B : endpoints, N: points (not intervals) 
from numpy import * 
A = 0.0; B = 3.0; N = 100 
h = (B - A)/(N - 1) #length of little intervals
sum = 0.0 # initialization 
for i in range(1, N + 1): # trap rule 
    t = A + (i-1)*h #evaluation point
    if ((i == 1) or (i == N)): 
        w = h/2.0 # end width wt=h/2 
    else: 
        w = h 
    sum = sum + w * t * t 
    print('sum = ', sum) # print integral 
    print("Enter and return a character to finish") 
    s = input()
# Out:
# sum =  0.0
# Enter and return a character to finish
#
# sum =  2.7826474107465846e-05
# Enter and return a character to finish
#
# sum =  0.00013913237053732924
# Enter and return a character to finish
#
# sum =  0.0003895706375045218
# Enter and return a character to finish
#
# sum =  0.0008347942232239754
# Enter and return a character to finish
#
# sum =  0.0015304560759106215
# Enter and return a character to finish
#
# sum =  0.0025322091437793917
# Enter and return a character to finish
#
# sum =  0.003895706375045218
# Enter and return a character to finish
#
# sum =  0.005676600717923032
# Enter and return a character to finish
#
# sum =  0.007930545120627765
# Enter and return a character to finish
#
# sum =  0.01071319253137435
# Enter and return a character to finish
#
# sum =  0.014080195898377718
# Enter and return a character to finish
#
# sum =  0.0180872081698528
# Enter and return a character to finish
#
# sum =  0.022789882294014525
# Enter and return a character to finish
#
# sum =  0.02824387121907783
# Enter and return a character to finish
#
# sum =  0.03450482789325764
# Enter and return a character to finish
#
# sum =  0.0416284052647689
# Enter and return a character to finish
#
# sum =  0.04967025628182653
# Enter and return a character to finish
#
# sum =  0.05868603389264546
# Enter and return a character to finish
#
# sum =  0.06873139104544064
# Enter and return a character to finish
#
# sum =  0.07986198068842698
# Enter and return a character to finish
#
# sum =  0.09213345576981942
# Enter and return a character to finish
#
# sum =  0.1056014692378329
# Enter and return a character to finish
#
# sum =  0.12032167404068234
# Enter and return a character to finish
#
# sum =  0.13634972312658267
# Enter and return a character to finish
#
# sum =  0.15374126944374883
# Enter and return a character to finish
#
# sum =  0.17255196594039574
# Enter and return a character to finish
#
# sum =  0.19283746556473833
# Enter and return a character to finish
#
# sum =  0.21465342126499154
# Enter and return a character to finish
#
# sum =  0.23805548598937032
# Enter and return a character to finish
#
# sum =  0.2630993126860896
# Enter and return a character to finish
#
# sum =  0.2898405543033643
# Enter and return a character to finish
#
# sum =  0.31833486378940934
# Enter and return a character to finish
#
# sum =  0.3486378940924396
# Enter and return a character to finish
#
# sum =  0.3808052981606701
# Enter and return a character to finish
#
# sum =  0.41489272894231577
# Enter and return a character to finish
#
# sum =  0.4509558393855915
# Enter and return a character to finish
#
# sum =  0.48905028243871224
# Enter and return a character to finish
#
# sum =  0.529231711049893
# Enter and return a character to finish
#
# sum =  0.5715557781673485
# Enter and return a character to finish
#
# sum =  0.6160781367392938
# Enter and return a character to finish
#
# sum =  0.6628544397139439
# Enter and return a character to finish
#
# sum =  0.7119403400395136
# Enter and return a character to finish
#
# sum =  0.7633914906642179
# Enter and return a character to finish
#
# sum =  0.8172635445362717
# Enter and return a character to finish
#
# sum =  0.8736121546038901
# Enter and return a character to finish
#
# sum =  0.9324929738152878
# Enter and return a character to finish
#
# sum =  0.9939616551186798
# Enter and return a character to finish
#
# sum =  1.0580738514622812
# Enter and return a character to finish
#
# sum =  1.1248852157943066
# Enter and return a character to finish
#
# sum =  1.1944514010629712
# Enter and return a character to finish
#
# sum =  1.2668280602164899
# Enter and return a character to finish
#
# sum =  1.3420708462030775
# Enter and return a character to finish
#
# sum =  1.420235411970949
# Enter and return a character to finish
#
# sum =  1.5013774104683195
# Enter and return a character to finish
#
# sum =  1.5855524946434036
# Enter and return a character to finish
#
# sum =  1.6728163174444166
# Enter and return a character to finish
#
# sum =  1.7632245318195732
# Enter and return a character to finish
#
# sum =  1.8568327907170883
# Enter and return a character to finish
#
# sum =  1.953696747085177
# Enter and return a character to finish
#
# sum =  2.053872053872054
# Enter and return a character to finish
#
# sum =  2.1574143640259345
# Enter and return a character to finish
#
# sum =  2.264379330495033
# Enter and return a character to finish
#
# sum =  2.374822606227565
# Enter and return a character to finish
#
# sum =  2.488799844171745
# Enter and return a character to finish
#
# sum =  2.606366697275788
# Enter and return a character to finish
#
# sum =  2.7275788184879093
# Enter and return a character to finish
#
# sum =  2.8524918607563237
# Enter and return a character to finish
#
# sum =  2.9811614770292456
# Enter and return a character to finish
#
# sum =  3.1136433202548903
# Enter and return a character to finish
#
# sum =  3.249993043381473
# Enter and return a character to finish
#
# sum =  3.3902662993572084
# Enter and return a character to finish
#
# sum =  3.534518741130311
# Enter and return a character to finish
#
# sum =  3.6828060216489966
# Enter and return a character to finish
#
# sum =  3.8351837938614795
# Enter and return a character to finish
#
# sum =  3.991707710715975
# Enter and return a character to finish
#
# sum =  4.152433425160698
# Enter and return a character to finish
#
# sum =  4.317416590143863
# Enter and return a character to finish
#
# sum =  4.486712858613686
# Enter and return a character to finish
#
# sum =  4.66037788351838
# Enter and return a character to finish
#
# sum =  4.8384673178061615
# Enter and return a character to finish
#
# sum =  5.021036814425245
# Enter and return a character to finish
#
# sum =  5.208142026323846
# Enter and return a character to finish
#
# sum =  5.399838606450178
# Enter and return a character to finish
#
# sum =  5.596182207752457
# Enter and return a character to finish
#
# sum =  5.797228483178897
# Enter and return a character to finish
#
# sum =  6.003033085677715
# Enter and return a character to finish
#
# sum =  6.213651668197124
# Enter and return a character to finish
#
# sum =  6.429139883685339
# Enter and return a character to finish
#
# sum =  6.649553385090576
# Enter and return a character to finish
#
# sum =  6.874947825361049
# Enter and return a character to finish
#
# sum =  7.105378857444974
# Enter and return a character to finish
#
# sum =  7.340902134290564
# Enter and return a character to finish
#
# sum =  7.581573308846036
# Enter and return a character to finish
#
# sum =  7.827448034059604
# Enter and return a character to finish
#
# sum =  8.078581962879484
# Enter and return a character to finish
#
# sum =  8.335030748253889
# Enter and return a character to finish
#
# sum =  8.596850043131035
# Enter and return a character to finish
#
# sum =  8.864095500459136
# Enter and return a character to finish
#
# sum =  9.000459136822773
# Enter and return a character to finish
